# %% [markdown]
# # Lab Instructions
#
# Find a dataset that interests you. I'd recommend starting on [Kaggle](https://www.kaggle.com/). Read through all of the material about the dataset and download a .CSV file.
#
# 1. Write a short summary of the data.  Where did it come from?  How was it collected?  What are the features in the data?  Why is this dataset interesting to you?
#
# 2. Identify 5 interesting questions about your data that you can answer using Pandas methods.
#
# 3. Answer those questions!  You may use any method you want (including LLMs) to help you write your code; however, you should use Pandas to find the answers.  LLMs will not always write code in this way without specific instruction.
#
# 4. Write the answer to your question in a text box underneath the code you used to calculate the answer.

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\manny\Downloads\archive\ai_jobs_global.csv")

df.head()
# Out:
#               job_title company        country           city  salary_min  \
# 0           AI Engineer   Jobot  United States   Mount Carmel    160000.0
# 1           AI Engineer   Jobot  United States        The Gap    175000.0
# 2           AI Engineer   Jobot  United States      Nashville    218000.0
# 3  Frontend/AI Engineer   Jobot  United States  New York City    112000.0
# 4   AI Engineering Lead   Jobot  United States         Irvine     92000.0
#
#    salary_max currency  remote_type experience_level required_skills  \
# 0    160000.0      USD  Unspecified             Lead             RAG
# 1    175000.0      USD  Unspecified             Lead             RAG
# 2    218000.0      USD  Unspecified             Lead             RAG
# 3    112000.0      USD  Unspecified        Mid-level             NaN
# 4     92000.0      USD  Unspecified           Senior             NaN
#
#   posted_date  source                                    job_description
# 0  2026-02-16  Adzuna  RAG - Vector Databases - Cloud - AI/ML This Jo...
# 1  2026-02-16  Adzuna  RAG - Vector Databases - Cloud - AI/ML This Jo...
# 2  2026-02-16  Adzuna  RAG - Vector Databases - Cloud - AI/ML This Jo...
# 3  2026-02-16  Adzuna  Manufacturing Company looking for Business Sys...
# 4  2026-02-16  Adzuna  Lead Financial Insights and Reporting as a Sen...

# %%
df["job_title"].value_counts().head(10)
# Out:
# job_title
# Data Scientist                                    281
# AI Engineer                                       270
# Machine Learning Engineer (PhD Intern)            173
# Machine Learning Engineer                         110
# Senior Data Scientist                             105
# Generative AI Automation Engineer - Remote Job     98
# Senior Machine Learning Engineer                   71
# ML/LLM Operations Engineer                         53
# AI Research Scientist - Language - MRS AI          49
# Machine Learning Operations (MLOps) Intern         48
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(10)
# Out:
# country
# United States     1837
# United Kingdom    1185
# Canada            1068
# Germany            944
# Australia          739
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['job_title', 'company', 'country', 'city', 'salary_min', 'salary_max',
#        'currency', 'remote_type', 'experience_level', 'required_skills',
#        'posted_date', 'source', 'job_description'],
#       dtype='object')

# %%
df["salary_mid"] = (df["salary_min"] + df["salary_max"]) / 2
df["salary_mid"].mean()
# Out:
# np.float64(114851.60227613058)

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Instacart                     198
# Mercor                        102
# EnthuZiastic                   98
# Meta                           91
# Oracle                         83
# Lockheed Martin                76
# mycareernow GmbH               61
# Mindrift                       57
# Bright Vision Technologies     52
# Evolent                        52
# Name: count, dtype: int64

# %%
df["experience_level"].value_counts().head(5)
# Out:
# experience_level
# Mid-level     3264
# Senior        1470
# Lead           609
# Junior         253
# Management     177
# Name: count, dtype: int64
